# %%
# !pip install pandas
# !pip install numpy
# !pip install seaborn
# !pip install matplotlib
# Out:
# Requirement already satisfied: pandas in c:\users\ayuresh\appdata\local\programs\python\python311\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\ayuresh\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ayuresh\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ayuresh\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ayuresh\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\ayuresh\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: numpy in c:\users\ayuresh\appdata\local\programs\python\python311\lib\site-packages (2.0.1)
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\ayuresh\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (2.0.1)
# Requirement already satisfied: pandas>=1.2 in c:\users\ayuresh\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\ayuresh\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (3.9.1.post1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ayuresh\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ayuresh\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ayuresh\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ayuresh\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\ayuresh\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\ayuresh\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ayuresh\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ayuresh\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ayuresh\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ayuresh\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\ayuresh\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Requirement already satisfied: matplotlib in c:\users\ayuresh\appdata\local\programs\python\python311\lib\site-packages (3.9.1.post1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ayuresh\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ayuresh\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ayuresh\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ayuresh\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\users\ayuresh\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (2.0.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\ayuresh\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\ayuresh\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ayuresh\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ayuresh\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\ayuresh\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns 
# %matplotlib inline

# %%
df = pd.read_csv("C:/Users/Ayuresh/Downloads/Loan Prediction Dataset.csv")
df = pd.read_csv("C:/Users/Ayuresh/Downloads/Loan Prediction Dataset.csv")
print(df.head())
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
# find the null values 
df.isnull().sum
# Out:
# <bound method DataFrame.sum of      Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0      False   False    False       False      False          False
# 1      False   False    False       False      False          False
# 2      False   False    False       False      False          False
# 3      False   False    False       False      False          False
# 4      False   False    False       False      False          False
# ..       ...     ...      ...         ...        ...            ...
# 609    False   False    False       False      False          False
# 610    False   False    False       False      False          False
# 611    False   False    False       False      False          False
# 612    False   False    False       False      False          False
# 613    False   False    False       False      False          False
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              False              False        True             False
# 1              False              False       False             False
# 2              False              False       False             False
# 3              False              False       False             False
# 4              False              False       False             False
# ..               ...                ...         ...               ...
# 609            False              False       False             False
# 610            False              False       False             False
# 611            False              False       False             False
# 612            False              False       False             False
# 613            False              False       False             False
#
#      Credit_History  Property_Area  Loan_Status
# 0             False          False        False
# 1             False          False        False
# 2             False          False        False
# 3             False          False        False
# 4             False          False        False
# ..              ...            ...          ...
# 609           False          False        False
# 610           False          False        False
# 611           False          False        False
# 612           False          False        False
# 613           False          False        False
#
# [614 rows x 13 columns]>

# %%
#fill the missing valuse for numerical terms
df['LoanAmount'] = df['LoanAmount'].fillna(df['LoanAmount'].mean())
df['Loan_Amount_Term']= df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mean())
df['Credit_History'] = df['Credit_History'].fillna(df['Credit_History'].mean())

# %%
df['Gender'] = df['Gender'].fillna(df['Gender'].mode()[0])
df['Married'] = df['Married'].fillna(df['Married'].mode()[0])
df['Dependents'] = df['Dependents'].fillna(df['Dependents'].mode()[0])
df['Self_Employed'] = df['Self_Employed'].fillna(df['Self_Employed'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
#catergarical analysis
sns.countplot(df['Gender'])
# Out:
# <Axes: xlabel='count', ylabel='Gender'>

# %%
sns.countplot(df['Married'])
# Out:
# <Axes: xlabel='count', ylabel='Married'>

# %%
sns.countplot(df['Dependents'])
# Out:
# <Axes: xlabel='count', ylabel='Dependents'>

# %%
sns.countplot(df['Education'])
# Out:
# <Axes: xlabel='count', ylabel='Education'>

# %%
sns.countplot(df['Self_Employed'])
# Out:
# <Axes: xlabel='count', ylabel='Self_Employed'>

# %%
sns.countplot(df['Property_Area'])
# Out:
# <Axes: xlabel='count', ylabel='Property_Area'>

# %%
sns.countplot(df['Loan_Status'])
# Out:
# <Axes: xlabel='count', ylabel='Loan_Status'>

# %%
#numerical analysis
df.columns = df.columns.str.strip()  # Remove any leading/trailing spaces in column names
sns.distplot(df['ApplicantIncome'])
# Out:
# C:\Users\Ayuresh\AppData\Local\Temp\ipykernel_7152\3696636272.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['ApplicantIncome'])
# <Axes: xlabel='ApplicantIncome', ylabel='Density'>

# %%
#apply 
df['ApplicantIncome'] = np.log(df['ApplicantIncome'])

# %%
sns.distplot(df['ApplicantIncome'])
# Out:
# C:\Users\Ayuresh\AppData\Local\Temp\ipykernel_7152\2349853404.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['ApplicantIncome'])
# <Axes: xlabel='ApplicantIncome', ylabel='Density'>

# %%
df.columns = df.columns.str.strip()
sns.distplot(df['CoapplicantIncome'])
# Out:
# C:\Users\Ayuresh\AppData\Local\Temp\ipykernel_7152\123773229.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['CoapplicantIncome'])
# <Axes: xlabel='CoapplicantIncome', ylabel='Density'>

# %%
df["CoapplicantIncome"]= np.log(df['ApplicantIncome'])
sns.distplot(df['ApplicantIncome'])
# Out:
# C:\Users\Ayuresh\AppData\Local\Temp\ipykernel_7152\102713017.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['ApplicantIncome'])
# <Axes: xlabel='ApplicantIncome', ylabel='Density'>

# %%
sns.distplot(df['LoanAmount'])
# Out:
# C:\Users\Ayuresh\AppData\Local\Temp\ipykernel_7152\413488336.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['LoanAmount'])
# <Axes: xlabel='LoanAmount', ylabel='Density'>

# %%
df["LoanAmount"]= np.log(df['LoanAmount'])
sns.distplot(df['LoanAmount'])
# Out:
# C:\Users\Ayuresh\AppData\Local\Temp\ipykernel_7152\2310438515.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['LoanAmount'])
# <Axes: xlabel='LoanAmount', ylabel='Density'>

# %%
sns.displot(df['Loan_Amount_Term'])

# %%
df["Loan_Amount_Term"]= np.log(df['Loan_Amount_Term'])
sns.distplot(df['Loan_Amount_Term'])
# Out:
# C:\Users\Ayuresh\AppData\Local\Temp\ipykernel_7152\2015860035.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Loan_Amount_Term'])
# <Axes: xlabel='Loan_Amount_Term', ylabel='Density'>

# %%
sns.distplot(df['Credit_History'])
# Out:
# C:\Users\Ayuresh\AppData\Local\Temp\ipykernel_7152\4144326787.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Credit_History'])
# <Axes: xlabel='Credit_History', ylabel='Density'>

# %%
#creation of new attribute
df['Total_Income'] = df['ApplicantIncome'] + df['CoapplicantIncome']
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0         8.674026           2.160333    4.986426          5.886104
# 1         8.430109           2.131810    4.852030          5.886104
# 2         8.006368           2.080237    4.189655          5.886104
# 3         7.856707           2.061368    4.787492          5.886104
# 4         8.699515           2.163267    4.948760          5.886104
#
#    Credit_History Property_Area Loan_Status  Total_Income
# 0             1.0         Urban           Y     10.834359
# 1             1.0         Rural           N     10.561919
# 2             1.0         Urban           Y     10.086605
# 3             1.0         Urban           Y      9.918074
# 4             1.0         Urban           Y     10.862782

# %%
df['ApplicantIncomeLog'] = np.log(df['ApplicantIncome'])
sns.distplot(df['ApplicantIncomeLog'])
# Out:
# C:\Users\Ayuresh\AppData\Local\Temp\ipykernel_7152\3021680648.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['ApplicantIncomeLog'])
# <Axes: xlabel='ApplicantIncomeLog', ylabel='Density'>

# %%
df["CoapplicantIncomeLog"]= np.log(df['ApplicantIncome'])
sns.distplot(df['ApplicantIncome'])
# Out:
# C:\Users\Ayuresh\AppData\Local\Temp\ipykernel_7152\3803704083.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['ApplicantIncome'])
# <Axes: xlabel='ApplicantIncome', ylabel='Density'>

# %%
df["LoanAmountLog"]= np.log(df['LoanAmount'])
sns.distplot(df['LoanAmountLog'])
# Out:
# C:\Users\Ayuresh\AppData\Local\Temp\ipykernel_7152\997800160.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['LoanAmountLog'])
# <Axes: xlabel='LoanAmountLog', ylabel='Density'>

# %%
df["Loan_Amount_Term_Log"]= np.log(df['Loan_Amount_Term'])
sns.distplot(df['Loan_Amount_Term_Log'])
# Out:
# C:\Users\Ayuresh\AppData\Local\Temp\ipykernel_7152\1225147826.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Loan_Amount_Term_Log'])
# <Axes: xlabel='Loan_Amount_Term_Log', ylabel='Density'>

# %%
df["Total_Income_Log"]= np.log(df['Total_Income'])
sns.distplot(df['Total_Income_Log'])
# Out:
# C:\Users\Ayuresh\AppData\Local\Temp\ipykernel_7152\666897248.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Total_Income_Log'])
# <Axes: xlabel='Total_Income_Log', ylabel='Density'>

# %%
# Select only numeric columns
numeric_df = df.select_dtypes(include=[np.number])
corr = numeric_df.corr()
sns.heatmap(corr, annot=True, cmap="BuPu")  # Changed cmap to 'BuPu' as 'BuFu' doesn't exist
# Out:
# <Axes: >

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  ...  \
# 0         8.674026           2.160333    4.986426          5.886104  ...
# 1         8.430109           2.131810    4.852030          5.886104  ...
# 2         8.006368           2.080237    4.189655          5.886104  ...
# 3         7.856707           2.061368    4.787492          5.886104  ...
# 4         8.699515           2.163267    4.948760          5.886104  ...
#
#    Property_Area Loan_Status Total_Income  ApplicantIncomeorg  \
# 0          Urban           Y    10.834359            2.160333
# 1          Rural           N    10.561919            2.131810
# 2          Urban           Y    10.086605            2.080237
# 3          Urban           Y     9.918074            2.061368
# 4          Urban           Y    10.862782            2.163267
#
#    ApplicantIncomeLog  CoapplicantIncomeLog  LoanAmountLog  \
# 0            2.160333              2.160333       1.606719
# 1            2.131810              2.131810       1.579397
# 2            2.080237              2.080237       1.432618
# 3            2.061368              2.061368       1.566007
# 4            2.163267              2.163267       1.599137
#
#    Loan_Amount_TermLog  Loan_Amount_Term_Log  Total_Income_Log
# 0             1.772594              1.772594          2.382722
# 1             1.772594              1.772594          2.357255
# 2             1.772594              1.772594          2.311208
# 3             1.772594              1.772594          2.294359
# 4             1.772594              1.772594          2.385342
#
# [5 rows x 21 columns]

# %%
#drop unnessary columns
cols = ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term', 'Total_Income','Loan_ID','CoapplicantIncomeLog']
df = df.drop(columns=cols,axis=1)
df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  Credit_History  \
# 0   Male      No          0      Graduate            No             1.0
# 1   Male     Yes          1      Graduate            No             1.0
# 2   Male     Yes          0      Graduate           Yes             1.0
# 3   Male     Yes          0  Not Graduate            No             1.0
# 4   Male      No          0      Graduate            No             1.0
#
#   Property_Area Loan_Status  ApplicantIncomeorg  ApplicantIncomeLog  \
# 0         Urban           Y            2.160333            2.160333
# 1         Rural           N            2.131810            2.131810
# 2         Urban           Y            2.080237            2.080237
# 3         Urban           Y            2.061368            2.061368
# 4         Urban           Y            2.163267            2.163267
#
#    LoanAmountLog  Loan_Amount_TermLog  Loan_Amount_Term_Log  Total_Income_Log
# 0       1.606719             1.772594              1.772594          2.382722
# 1       1.579397             1.772594              1.772594          2.357255
# 2       1.432618             1.772594              1.772594          2.311208
# 3       1.566007             1.772594              1.772594          2.294359
# 4       1.599137             1.772594              1.772594          2.385342

# %%
from sklearn.preprocessing import LabelEncoder

# Define the columns to encode
cols = ['Gender', 'Married', 'Education', 'Self_Employed', 'Property_Area', 'Loan_Status', 'Dependents']
cols = ['Dependents']
# Initialize the LabelEncoder
le = LabelEncoder()

# Apply LabelEncoder to each column
for col in cols:
    if col in df.columns:  # Check if the column exists
        # Fill missing values to avoid errors during encoding
        df[col] = df[col].fillna('Missing')
        df[col] = le.fit_transform(df[col])
    else:
        print(f"Column '{col}' does not exist in the DataFrame.")

# %%
df.head()
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  Credit_History  \
# 0       1        0           0          0              0             1.0
# 1       1        1           1          0              0             1.0
# 2       1        1           0          0              1             1.0
# 3       1        1           0          1              0             1.0
# 4       1        0           0          0              0             1.0
#
#    Property_Area  Loan_Status  ApplicantIncomeorg  ApplicantIncomeLog  \
# 0              2            1            2.160333            2.160333
# 1              0            0            2.131810            2.131810
# 2              2            1            2.080237            2.080237
# 3              2            1            2.061368            2.061368
# 4              2            1            2.163267            2.163267
#
#    LoanAmountLog  Loan_Amount_TermLog  Loan_Amount_Term_Log  Total_Income_Log
# 0       1.606719             1.772594              1.772594          2.382722
# 1       1.579397             1.772594              1.772594          2.357255
# 2       1.432618             1.772594              1.772594          2.311208
# 3       1.566007             1.772594              1.772594          2.294359
# 4       1.599137             1.772594              1.772594          2.385342

# %%
x = df.drop(columns=['Loan_Status'], axis=1)
y = df['Loan_Status']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test , y_train, y_test = train_test_split(x,y,test_size=0.25,random_state=42)

# %%
#classify function
from sklearn.model_selection import cross_val_score
def classify(model ,x,y):
    x_train, x_test , y_train, y_test = train_test_split(x,y,test_size=0.25,random_state=42)
    model.fit(x_train,y_train)
    print('Acciracy is',model.score(x_test,y_test)*100)
    score = cross_val_score(model,x,y,cv=5)
    print('Cross validation is,',np.mean(score)*100)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
classify(model,x,y)
# Out:
# Acciracy is 77.27272727272727
# Cross validation is, 80.9462881514061

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
classify(model,x,y)
# Out:
# Acciracy is 75.97402597402598
# Cross validation is, 71.33946421431428

# %%
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier
model = RandomForestClassifier()
classify(model,x,y)
# Out:
# Acciracy is 79.87012987012987
# Cross validation is, 78.01412768226042

# %%
model = ExtraTreesClassifier()
classify(model,x,y)
# Out:
# Acciracy is 77.27272727272727
# Cross validation is, 77.03851792616287

# %%
model = RandomForestClassifier(n_estimators=100 , min_samples_split=25,max_depth=7,max_features=1)
classify(model,x,y)
# Out:
# Acciracy is 74.67532467532467
# Cross validation is, 78.50059976009595

# %%
model = RandomForestClassifier()
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
from sklearn.metrics import confusion_matrix
y_pred = model.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[28, 26],
#        [ 6, 94]])

# %%
sns.heatmap(cm , annot=True)
# Out:
# <Axes: >
